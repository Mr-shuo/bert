# %%
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, Flatten

from keras.datasets import mnist
from keras.utils import np_utils


(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1, 1, 28, 28)/255
X_test = X_test.reshape(-1, 1, 28, 28)/255
y_train = np_utils.to_categorical(y_train, num_classes=10)
y_test = np_utils.to_categorical(y_test, num_classes=10)
print(X_train.shape)

import numpy as np
np.random.seed(1337)  # for reproducibility
from keras.datasets import mnist
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

model = Sequential()
model.add(Convolution2D(
    batch_input_shape = (None, 1, 28, 28),
    filters = 32,
    kernel_size = 5,
    strides = 1,
    padding = 'same',
    data_format = 'channels_first',
))

model.add(Activation('relu'))

model.add(MaxPooling2D(
    pool_size = 2,
    strides = 2,
    padding = 'same',
    data_format = 'channels_first',
))

model.add(Convolution2D(
    64, 5, strides = 1, padding = 'same', data_format = 'channels_first'
))

model.add(Activation('relu'))
model.add(MaxPooling2D(2,2,'same',data_format='channels_first'))

model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))

model.add(Dense(10))
model.add(Activation('softmax'))
adam = Adam(lr=1e-4)

model.compile(optimizer=adam,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32,)

print('Testing------------')
loss, accuracy = model.evaluate(X_test, y_test)
print('test loss:', loss)
print('test accuracy:', accuracy)
# Out:
# (60000, 1, 28, 28)
# Epoch 1/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2118 - accuracy: 0.9395
# Epoch 2/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0601 - accuracy: 0.9814
# Epoch 3/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0416 - accuracy: 0.9875
# Epoch 4/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0321 - accuracy: 0.9899
# Epoch 5/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0242 - accuracy: 0.9924
# Epoch 6/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0200 - accuracy: 0.9936
# Epoch 7/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0156 - accuracy: 0.9950
# Epoch 8/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0116 - accuracy: 0.9966
# Epoch 9/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0099 - accuracy: 0.9968
# Epoch 10/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0084 - accuracy: 0.9974
# Epoch 11/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 12/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0061 - accuracy: 0.9982
# Epoch 13/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 14/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 15/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 16/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 17/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 18/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 19/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 20/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 21/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 22/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 23/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 24/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 6.9952e-04 - accuracy: 0.9998
# Epoch 25/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 26/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 27/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 6.8641e-04 - accuracy: 0.9999
# Epoch 28/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 29/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 9.4960e-04 - accuracy: 0.9998
# Epoch 30/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 7.9247e-04 - accuracy: 0.9997
# Epoch 31/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 32/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.9938e-04 - accuracy: 0.9999
# Epoch 33/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 7.1577e-04 - accuracy: 0.9998
# Epoch 34/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 35/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 36/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.2933e-04 - accuracy: 1.0000
# Epoch 37/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.7888e-05 - accuracy: 1.0000
# Epoch 38/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 39/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 6.4112e-04 - accuracy: 0.9998
# Epoch 40/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 7.0533e-04 - accuracy: 0.9998
# Epoch 41/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 5.1051e-04 - accuracy: 0.9999
# Epoch 42/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 3.9736e-05 - accuracy: 1.0000
# Epoch 43/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 44/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 5.8111e-04 - accuracy: 0.9998
# Epoch 45/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 8.2774e-04 - accuracy: 0.9998
# Epoch 46/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 9.7667e-05 - accuracy: 1.0000
# Epoch 47/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 8.4946e-06 - accuracy: 1.0000
# Epoch 48/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 4.1857e-06 - accuracy: 1.0000
# Epoch 49/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.1336e-06 - accuracy: 1.0000
# Epoch 50/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0022 - accuracy: 0.9993
# Testing------------
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0379 - accuracy: 0.9929
# test loss: 0.03789686784148216
# test accuracy: 0.992900013923645
